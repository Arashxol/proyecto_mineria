# %% [markdown]
# ## TALLER APLICADO : MANOS A LOS DATOS

# %% [markdown]
# GRUPO 7
#
# HEALTHCARE
#
# INTEGRANTES:
#
# JHOEL JULIO QUISPE QUISPE
#
# CESAR AUGUSTO PERALES LOPEZ
#
# SEBASTIAN MARTIN GOMEZ TRINCADO
#
# CRIS KLEBER BALLON CHIPANA
#
# MARCELO VELARDE ALI

# %% [markdown]
# 1. El "Censo" de Vacíos (Integridad)
# Pregunta: ¿Cuál es el porcentaje de datos faltantes en sus 3 variables más importantes?

# %%
import pandas as pd
variables_top = ['Medical Condition', 'Medication', 'Insurance Provider']
porcentaje_faltantes = df_bfv[variables_top].isnull().mean() * 100

print(porcentaje_faltantes)
# Out:
# Medical Condition     0.0
# Medication            0.0
# Insurance Provider    0.0
# dtype: float64

# %% [markdown]
# 2. Los "Rebeldes" del Grupo (Outliers)
# Pregunta: Al ver sus Boxplots, ¿existen valores atípicos extremos?
#
# Acción: Identifiquen un dato que parezca imposible (ej. un precio de $0 o una edad de 150 años). ¿Es un error de carga o es un caso real muy especial?

# %%
sns.boxplot(x=df_bfv["Medical Condition"], color="lightgreen")
plt.title("Datos")
plt.xlabel("Enfermedad")
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# 3. El Termómetro de Relación (Correlación)
# Pregunta: ¿Qué variable numérica parece tener la relación más fuerte con su "objetivo" (Target)?
#
# Acción: Muestren un Scatter Plot o una Matriz de Correlación. Si no hay relación visual, ¿creen que necesitan crear una variable nueva (Feature Engineering)?

# %%
corr = df_bfv[['Age','Room Number']].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Mapa de calor de correlaciones")
plt.show()

# %% [markdown]
# 4. La Forma de los Datos (Distribución)
# Pregunta: ¿Sus datos numéricos forman una "campana de Gauss" o están muy cargados hacia un lado (sesgados)?
#
# Acción: Si están sesgados, ¿cómo podría esto afectar a un modelo de minería (ej. un modelo que prediga solo los casos más comunes)?

# %%
sns.histplot(df_bfv["Blood Type"], bins=10, kde=True, color="skyblue")
plt.title("Datos")
plt.xlabel("Tipo de Sangre")
plt.ylabel("Cantidada de personas")
plt.show()

# %% [markdown]
# 5. El Cambio de Rumbo (Hipótesis)
# Pregunta: Después de este análisis rápido, ¿su idea original del problema sigue siendo la misma?
#
# Acción: Digan una cosa que les haya sorprendido de los datos que no esperaban al inicio de la clase.

# %% [markdown]
# Si , lo que nos sorprende es la cantidad de datos que estan practicamente completos.

# %% [markdown]
# DATOS

# %%
df_bfv = pd.read_csv('healthcare_dataset.csv')
df_bfv.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %% [markdown]
# ¿ Cual es la variable con mas datos faltantes?

# %%
df_bfv.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64
